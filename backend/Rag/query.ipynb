# %%
# %pip install langchain_huggingface

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEmbeddings

# %%
from llama_cpp import Llama

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEmbeddings,HuggingFaceEndpoint
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain_huggingface import ChatHuggingFace, HuggingFaceEmbeddings,HuggingFaceEndpoint
#
# ModuleNotFoundError: No module named 'langchain_huggingface'

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from llama_cpp import Llama
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain.embeddings import HuggingFaceEmbeddings
#       2 from langchain.vectorstores import Chroma
#       3 from llama_cpp import Llama
#
# ImportError: cannot import name 'HuggingFaceEmbeddings' from 'langchain.embeddings' (a:\Programming-Language-\Local-LLM-PRoject\Programing\Testing-code\.venv\lib\site-packages\langchain\embeddings\__init__.py)
